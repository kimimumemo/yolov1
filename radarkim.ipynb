# %% [markdown]
# <a href="https://colab.research.google.com/github/kimimumemo/yolov1/blob/main/radarkim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Tue Aug 17 03:21:39 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P8    27W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/MyDrive/radarkim'
# Out:
# backup	darknet  darknet1  radarkim_foto  radarkim_weight

# %%
# !unzip '/content/drive/MyDrive/radarkim/radarkim_foto.zip' -d '/content/drive/MyDrive/radarkim'
# Out:
# Archive:  /content/drive/MyDrive/radarkim/radarkim_foto.zip
#    creating: /content/drive/MyDrive/radarkim/radarkim_foto/
#   inflating: /content/drive/MyDrive/radarkim/radarkim_foto/KIM_6.jpeg
#   inflating: /content/drive/MyDrive/radarkim/__MACOSX/radarkim_foto/._KIM_6.jpeg
#   inflating: /content/drive/MyDrive/radarkim/radarkim_foto/KIM_36.jpeg
#   inflating: /content/drive/MyDrive/radarkim/__MACOSX/radarkim_foto/._KIM_36.jpeg
#   inflating: /content/drive/MyDrive/radarkim/radarkim_foto/KIM_20.jpeg
#   inflating: /content/drive/MyDrive/radarkim/__MACOSX/radarkim_foto/._KIM_20.jpeg
#   inflating: /content/drive/MyDrive/radarkim/radarkim_foto/classes.txt
#   inflating: /content/drive/MyDrive/radarkim/__MACOSX/radarkim_foto/._classes.txt
#   inflating: /content/drive/MyDrive/radarkim/radarkim_foto/KIM_16.jpeg
#   inflating: /content/drive/MyDrive/radarkim/__MACOSX/radarkim_foto/._KIM_16.jpeg
#   inflating: /content/drive/MyDrive/radarkim/radarkim_foto/.DS_Store
# ...

# %%
# !git clone 'https://github.com/pjreddie/darknet' '/content/drive/MyDrive/radarkim/darknet'
# Out:
# Cloning into '/content/drive/MyDrive/radarkim/darknet'...
# remote: Enumerating objects: 5937, done.
# remote: Total 5937 (delta 0), reused 0 (delta 0), pack-reused 5937
# Receiving objects: 100% (5937/5937), 6.34 MiB | 5.34 MiB/s, done.
# Resolving deltas: 100% (3940/3940), done.
# Checking out files: 100% (979/979), done.

# %%
# !git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/MyDrive/radarkim/darknet1'
# Out:
# Cloning into '/content/drive/MyDrive/radarkim/darknet1'...
# remote: Enumerating objects: 15298, done.
# remote: Total 15298 (delta 0), reused 0 (delta 0), pack-reused 15298
# Receiving objects: 100% (15298/15298), 13.65 MiB | 6.40 MiB/s, done.
# Resolving deltas: 100% (10397/10397), done.
# Checking out files: 100% (2044/2044), done.

# %%
# %cd /content/drive/MyDrive/radarkim/darknet1
# Out:
# /content/drive/MyDrive/radarkim/darknet1

# %%
# !make
# Out:
# chmod +x *.sh

# %%
# %cd /content/drive/MyDrive/radarkim
# Out:
# /content/drive/MyDrive/radarkim

# %%
# !python radarkim_foto/creating-files-data-and-name.py

# %%
# !python radarkim_foto/creating-train-and-test-txt-files.py

# %%
# !darknet/darknet
# Out:
# usage: darknet/darknet <function>

# %%
# !darknet1/darknet detector train radarkim_foto/labelled_data.data darknet1/cfg/yolov3_custom.cfg radarkim_weight/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 14875, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.911858), count: 1, class_loss = 0.030745, iou_loss = 0.112423, total_loss = 0.143168
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# ...
